# %%
import glob
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
epc = '3008 33B2 DDD9 0140 0000 0000'

# %%
for file in glob.glob(os.path.join('d:\\atom\\exp\\20210307', '*.csv')):
    df = pd.read_csv(file).groupby('EPC').get_group(epc)
    plt.scatter(df['CHANNEL'], df['PHASE'])
    plt.title(file)
    plt.show()
    plt.scatter(df['CHANNEL'], df['RSSI'])
    plt.show()
