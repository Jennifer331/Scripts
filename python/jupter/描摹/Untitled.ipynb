# %%
import numpy as np
import pandas as pd

# use pandas to extract rainfall inches as a NumPy array
rainfall = pd.read_csv('data/Seattle2014.csv')['PRCP'].values
inches = rainfall / 254.0  # 1/10mm -> inches
inches.shape
# Out:
# (365,)

# %%
import seaborn; seaborn.set()

# %%
plt.hist(inches, 40);

# %%
rainy = (inches > 0)

days = np.arange(365)
summer = (days > 172) & (days < 262)

np.median(inches[rainy])
np.median(inches[rainy & ~summer])
# Out:
# 0.20078740157480315

# %%
mean = [0, 0]
cov = [[1, 2], [2, 5]]
rng = np.random.RandomState(42)
X = rng.multivariate_normal(mean, cov, 100)
X.shape
# Out:
# (100, 2)

# %%
import seaborn; seaborn.set()
plt.scatter(X[:, 0], X[:, 1]);

# %%
indices = np.random.choice(X.shape[0], 20, replace=False)
selection = X[indices]
plt.scatter(X[:, 0], X[:, 1], alpha=0.4)
plt.scatter(selection[:, 0], selection[:, 1], facecolor='none', edgecolors='black', s=150)

# %%
x = np.arange(10)
i = np.array([2, 1, 8, 4])
x[i] = 88
print(x)
# Out:
# [ 0 88 88  3 88  5  6  7 88  9]

# %%
x[i] -= 10
print(x)
# Out:
# [ 0 78 78  3 78  5  6  7 78  9]

# %%
x = np.zeros(10)
x[[0, 0]] = [4, 6]

# %%
x
# Out:
# array([6., 0., 0., 0., 0., 0., 0., 0., 0., 0.])

# %%
i = [2, 3, 3, 4, 4, 4]
x[i] += 1
x
# Out:
# array([6., 0., 1., 1., 1., 0., 0., 0., 0., 0.])

# %%
np.add.at(x, i, 1)

# %%
x
# Out:
# array([6., 0., 2., 3., 4., 0., 0., 0., 0., 0.])

# %%
np.random.seed(42)
x = np.random.randn(100)

bins = np.linspace(-5, 5, 20)
counts = np.zeros_like(bins)

i = np.searchsorted(bins, x)
np.add.at(counts, i, 1)

# %%
plt.plot(bins, counts, linestyle='steps')
# Out:
# <ipython-input-33-5c85b60d2441>:1: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   plt.plot(bins, counts, linestyle='steps')

# %%
plt.hist(x, bins, histtype='step')
# Out:
# (array([ 0.,  0.,  0.,  0.,  1.,  3.,  7.,  9., 23., 22., 17., 10.,  7.,
#          1.,  0.,  0.,  0.,  0.,  0.]),
#  array([-5.        , -4.47368421, -3.94736842, -3.42105263, -2.89473684,
#         -2.36842105, -1.84210526, -1.31578947, -0.78947368, -0.26315789,
#          0.26315789,  0.78947368,  1.31578947,  1.84210526,  2.36842105,
#          2.89473684,  3.42105263,  3.94736842,  4.47368421,  5.        ]),
#  <a list of 1 Patch objects>)

# %%
conts, edges = np.histogram(x, bins)

# %%
plt.plot(edges, counts, linestyle='steps')
# Out:
# <ipython-input-40-aeb35df3ac95>:1: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   plt.plot(edges, counts, linestyle='steps')

# %%
3  3
