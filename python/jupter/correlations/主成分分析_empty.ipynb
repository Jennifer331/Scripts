# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %%
import sys
sys.path.extend(['d:\\atom\\python'])

# %%
import data_manager as dm

# %%
df = dm.import_clean_data('nongfu_water.csv')

# %%
df.describe()
# Out:
#          DISTANCE       CHANNEL        RSSI       PHASE
# count  916.000000  9.160000e+02  916.000000  916.000000
# mean     0.335721  9.147566e+08  -40.745406    3.138306
# std      0.306738  7.192092e+06   12.443304    1.793374
# min      0.020000  9.027500e+08  -65.000000    0.006198
# 25%      0.080000  9.087500e+08  -54.013819    1.592850
# 50%      0.230000  9.147500e+08  -39.501256    3.111823
# 75%      0.680000  9.207500e+08  -33.500000    4.731560
# max      0.890000  9.272500e+08  -19.500000    6.264778

# %%
df['DISTANCE'].plot(kind='kde')

# %%
df['CHANNEL'].value_counts().plot(kind='pie')

# %%
# df = df.drop(columns=['PHASE'])

# %%
pca = PCA()
pca.fit(df)
# Out:
# PCA()

# %%
pca.components_
# Out:
# array([[-2.31461169e-09,  1.00000000e+00, -9.32596104e-08,
#         -4.68176017e-08],
#        [ 2.30775819e-02, -9.28098692e-08, -9.99702676e-01,
#          7.87304684e-03],
#        [ 7.90303349e-04, -4.75470441e-08, -7.85689913e-03,
#         -9.99968822e-01],
#        [ 9.99733365e-01,  4.49521422e-09,  2.30830844e-02,
#          6.08750140e-04]])

# %%
pca.explained_variance_
# Out:
# array([5.17261866e+13, 1.54477595e+02, 3.09343097e+00, 1.15443464e-02])
