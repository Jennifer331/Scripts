# %%
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
import pandas as pd
import os

# %%
folder_clean = 'd:\\atom\\python\\data\\cleaned'
folder_white = 'd:\\atom\\exp\\20210202'

# %%
df = pd.read_csv(os.path.join(folder_clean, 'white_empty.csv'))

# %%
df.describe()
# Out:
#           DISTANCE      CHANNEL         RSSI        PHASE
# count  1899.000000  1899.000000  1899.000000  1899.000000
# mean     68.593997   915.006187   -37.143150     3.163030
# std      59.182372     7.214193    10.745298     1.799549
# min       1.000000   902.750000   -72.060302     0.000000
# 25%      23.000000   908.750000   -41.501256     1.609940
# 50%      50.000000   915.250000   -35.500000     3.163300
# 75%     100.000000   921.250000   -29.487437     4.737549
# max     240.000000   927.250000   -21.000000     6.263853

# %%
df['DISTANCE'].unique()
# Out:
# array([  1,   2,   4,   5,   8,  11,  14,  17,  20,  23,  26,  29,  32,
#         35,  38,  41,  44,  47,  50,  53,  56,  59,  62,  65,  68,  76,
#         84,  92, 100, 108, 135, 140, 145, 155, 165, 175, 185, 240],
#       dtype=int64)

# %%
df['DISTANCE'].value_counts()
# Out:
# 50     50
# 23     50
# 44     50
# 41     50
# 38     50
# 35     50
# 32     50
# 29     50
# 26     50
# 20     50
# 185    50
# 17     50
# 14     50
# 11     50
# 8      50
# 5      50
# 4      50
# 2      50
# 47     50
# 1      50
# 53     50
# 56     50
# 175    50
# 165    50
# 155    50
# 145    50
# 140    50
# 135    50
# 108    50
# 100    50
# 92     50
# 84     50
# 76     50
# 68     50
# 65     50
# 62     50
# 59     50
# 240    49
# Name: DISTANCE, dtype: int64

# %%
df['CHANNEL'].value_counts()
# Out:
# 913.75    38
# 914.25    38
# 909.25    38
# 912.75    38
# 922.25    38
# 916.25    38
# 902.75    38
# 919.75    38
# 923.75    38
# 907.25    38
# 910.75    38
# 925.25    38
# 917.75    38
# 924.75    38
# 926.75    38
# 905.25    38
# 908.75    38
# 912.25    38
# 904.25    38
# 915.75    38
# 921.75    38
# 919.25    38
# 906.75    38
# 923.25    38
# 920.75    38
# 905.75    38
# 918.25    38
# 927.25    38
# 917.25    38
# 904.75    38
# 926.25    38
# 908.25    38
# 903.75    38
# 911.75    38
# 915.25    38
# 918.75    38
# 921.25    38
# 906.25    38
# 909.75    38
# 922.75    38
# 913.25    38
# 916.75    38
# 924.25    38
# 920.25    38
# 907.75    38
# 925.75    38
# 911.25    38
# 914.75    38
# 910.25    38
# 903.25    37
# Name: CHANNEL, dtype: int64

# %%
for name, group in df.groupby('DISTANCE'):
    plt.scatter(group['CHANNEL'], group['PHASE'])
    plt.title(str(name) + 'cm')
    plt.show()

# %%
for name, group in df.groupby('CHANNEL'):
    plt.scatter(group['DISTANCE'], group['PHASE'])
    plt.title(str(name) + 'Mhz')
    plt.show()
