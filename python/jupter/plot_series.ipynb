# %%
import matplotlib.pyplot as plt

# %%
data =[1, 2, 3, 17]
num = 4

# %%
plt.plot(list(range(len(data) - num, len(data))), data[-1-num+1:])
x_major_locator = plt.MultipleLocator(1)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
