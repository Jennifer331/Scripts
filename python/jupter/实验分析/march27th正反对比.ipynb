# %%
import os
import glob

# %%
folder = 'D:\\Atom\\python\\data\\cleaned\\grill\\sheet'
liquids = ['water', 'vinegar', 'oil', 'empty']
for l in liquids:
    df_front = pd.read_csv(os.path.join(folder, '000cm_front_%s_kde_sheet.csv' % l))
    plt.plot(df_front['CHANNEL'], df_front['RSSI'])
    df_tail = pd.read_csv(os.path.join(folder, '000cm_tail_%s_kde_sheet.csv' % l))
    plt.plot(df_tail['CHANNEL'], df_tail['RSSI'])
    plt.title(l)
    plt.legend(['front', 'tail'])
    plt.show()

# %%
for l in ['oil', 'empty']:
    df_front = pd.read_csv(os.path.join(folder, '100cm_front_%s_kde_sheet.csv' % l))
    plt.plot(df_front['CHANNEL'], df_front['RSSI'])
    df_tail = pd.read_csv(os.path.join(folder, '100cm_tail_%s_kde_sheet.csv' % l))
    plt.plot(df_tail['CHANNEL'], df_tail['RSSI'])
    plt.title(l)
    plt.legend(['front-%s' % l, 'tail-%s' % l])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-dbc86a2a4344> in <module>
#       2     df_front = pd.read_csv(os.path.join(folder, '100cm_front_%s_kde_sheet.csv' % l))
#       3     plt.plot(df_front['CHANNEL'], df_front['RSSI'])
# ----> 4     df_tail = pd.read_csv(os.path.join(folder, '100cm_tail_%s_kde_sheet.csv' % l))
#       5     plt.plot(df_tail['CHANNEL'], df_tail['RSSI'])
#       6     plt.title(l)
#
# ...

# %%
folder = 'D:\\Atom\\python\\data\\cleaned\\grill\\nosheet'
liquids = ['water', 'oil', 'empty', 'vinegar']

for l in liquids:
    df_front = pd.read_csv(os.path.join(folder, '000cm_front_%s_kde_nosheet.csv' % l))
    plt.plot(df_front['CHANNEL'], df_front['RSSI'])
    df_tail = pd.read_csv(os.path.join(folder, '000cm_tail_%s_kde_nosheet.csv' % l))
    plt.plot(df_tail['CHANNEL'], df_tail['RSSI'])
    plt.title(l)
    plt.legend(['front', 'tail'])
    plt.show()

# %%
folder = 'D:\\Atom\\python\\data\\cleaned\\grill\\sheet'
liquids = ['water', 'oil', 'empty', 'vinegar']

for l in liquids:
    df_front = pd.read_csv(os.path.join(folder, '000cm_front_%s_kde_sheet.csv' % l))
    plt.plot(df_front['CHANNEL'], df_front['PHASE'])
    df_tail = pd.read_csv(os.path.join(folder, '000cm_tail_%s_kde_sheet.csv' % l))
    plt.plot(df_tail['CHANNEL'], df_tail['PHASE'])
    plt.title(l)
    plt.legend(['front', 'tail'])
    plt.show()

# %%
folder = 'D:\\Atom\\python\\data\\cleaned\\grill\\nosheet'
liquids = ['water', 'oil', 'empty', 'vinegar']

for l in liquids:
    df_front = pd.read_csv(os.path.join(folder, '000cm_front_%s_kde_nosheet.csv' % l))
#     plt.plot(df_front['CHANNEL'], df_front['PHASE'])
    df_tail = pd.read_csv(os.path.join(folder, '000cm_tail_%s_kde_nosheet.csv' % l))
#     plt.plot(df_tail['CHANNEL'], df_tail['PHASE'])
    p1 = df_front['PHASE'].values
    p2 = df_tail['PHASE'].values
    p1 = np.unwrap(p1)
    p2 = np.unwrap(p2)
    plt.plot(df_front['CHANNEL'], (p2 - p1)/(4*np.pi)*33)
    plt.title(l)
    plt.legend(['front', 'tail'])
    plt.show()

# %%
folder = 'D:\\Atom\\python\\data\\cleaned\\grill\\nosheet'
liquids = ['water', 'vinegar', 'oil', 'empty']
for l in liquids:
    df_front = pd.read_csv(os.path.join(folder, '000cm_front_%s_kde_nosheet.csv' % l))
    plt.plot(df_front['CHANNEL'], df_front['RSSI'])
    df_tail = pd.read_csv(os.path.join(folder, '000cm_tail_%s_kde_nosheet.csv' % l))
    plt.plot(df_tail['CHANNEL'], df_tail['RSSI'])
    plt.title(l)
    plt.legend(['front', 'tail'])
    plt.show()

# %%
folder = 'D:\\Atom\\python\\data\\cleaned\\grill\\nosheet'
liquids = ['water', 'vinegar', 'oil', 'empty']

for l in liquids:
    df_front = pd.read_csv(os.path.join(folder, '100cm_front_%s_kde_nosheet.csv' % l))
    plt.plot(df_front['CHANNEL'], df_front['RSSI'])
    df_tail = pd.read_csv(os.path.join(folder, '100cm_tail_%s_kde_nosheet.csv' % l))
    plt.plot(df_tail['CHANNEL'], df_tail['RSSI'])
    plt.title(l)
    plt.legend(['front', 'tail'])
    plt.show()

# %%
folder = 'D:\\Atom\\python\\data\\cleaned\\grill\\noback'
liquids = ['water', 'water2', 'vinegar', 'oil', 'empty']

for l in liquids:
    df_front = pd.read_csv(os.path.join(folder, 'd1_%s_front_noback.csv' % l))
    plt.plot(df_front['CHANNEL'], df_front['RSSI'])
    df_tail = pd.read_csv(os.path.join(folder, 'd1_%s_tail_noback.csv' % l))
    plt.plot(df_tail['CHANNEL'], df_tail['RSSI'])
    plt.title(l)
    plt.legend(['front', 'tail'])
    plt.show()

# %%
folder = 'D:\\Atom\\python\\data\\cleaned\\grill\\noback'
dists = ['d1', 'd2', 'd3']

for d in dists:
    df_front = pd.read_csv(os.path.join(folder, '%s_water_front_noback.csv' % d))
    plt.plot(df_front['CHANNEL'], df_front['RSSI'])
    df_tail = pd.read_csv(os.path.join(folder, '%s_water_tail_noback.csv' % d))
    plt.plot(df_tail['CHANNEL'], df_tail['RSSI'])
    plt.title(d)
    plt.legend(['front', 'tail'])
    plt.show()

# %%
folder = 'D:\\Atom\\python\\data\\cleaned\\grill\\outdoor'
liquids = ['water', 'vinegar', 'oil', 'empty']

for l in liquids:
    df_front = pd.read_csv(os.path.join(folder, 'outdoor_d1_%s_front_kde_outdoor.csv' % l))
    plt.plot(df_front['CHANNEL'], df_front['RSSI'])
    df_tail = pd.read_csv(os.path.join(folder, 'outdoor_d1_%s_tail_kde_outdoor.csv' % l))
    plt.plot(df_tail['CHANNEL'], df_tail['RSSI'])
    plt.title(l)
    plt.legend(['front', 'tail'])
    plt.show()
