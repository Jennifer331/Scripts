# %%
import glob, os
import pickle
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号


folder = 'D:\\Atom\\python\\data\\cleaned\\outdoor'
front = pd.read_csv(os.path.join(folder, 'outdoor_oil_kde.csv'))
tail = pd.read_csv(os.path.join(folder, 'outdoor_oil_tail_kde.csv'))

# %%
front_head = front[front['DISTANCE'] <= 135]
for dist, group in front_head.groupby('CHANNEL'):
#     plt.plot(group['DISTANCE'], group['RSSI'])
    plt.plot(group['DISTANCE'], group['RSSI'], c='r')

for dist, group in tail.groupby('CHANNEL'):
#     plt.plot(group['DISTANCE'], group['RSSI'])
    plt.plot(group['DISTANCE'], group['RSSI'], c='g')

# %%
channels = [902.75, 903.25, 903.75, 904.25, 904.75, 905.25, 905.75, 906.25, 906.75, 907.25, 907.75, 908.25, 908.75,
            909.25, 909.75, 910.25, 910.75, 911.25, 911.75, 912.25, 912.75, 913.25, 913.75, 914.25, 914.75, 915.25,
            915.75, 916.25, 916.75, 917.25, 917.75, 918.25, 918.75, 919.25, 919.75, 920.25, 920.75, 921.25, 921.75,
            922.25, 922.75, 923.25, 923.75, 924.25, 924.75, 925.25, 925.75, 926.25, 926.75, 927.25]

for f in channels:
    f_g = front_head.groupby('CHANNEL').get_group(f)
    t_g = tail.groupby('CHANNEL').get_group(f)


    plt.plot(f_g['DISTANCE'], f_g['RSSI'], c='r')
    plt.plot(t_g['DISTANCE'], t_g['RSSI'], c='g')
    
    plt.title(f)
    plt.show()

# %% [markdown]
# 在相邻空间中，环境中反射体造成的多径情况相似，差别主要在于视距路径信号的变化，正面采集时，视距路径信号还会通过后壁反射叠加，反面采集时，视距路径会穿过液体。两次信号传播的差异主要在于在瓶内液体中的传播，与环境无关。

# %%
folder_outdoor = 'D:\\Atom\\python\\data\\cleaned\\outdoor\\front-tail'
front = pd.read_csv(os.path.join(folder_outdoor, 'outdoor_all_f_oil_kde.csv'))
tail = pd.read_csv(os.path.join(folder_outdoor, 'outdoor_all_t_oil_kde.csv'))

# %%
for dist, group in front.groupby('CHANNEL'):
    plt.plot(group['DISTANCE'], group['RSSI'], c='r')
    
for dist, group in tail.groupby('CHANNEL'):
    plt.plot(group['DISTANCE'], group['RSSI'], c='g')

# %%
dists = front['DISTANCE'].unique()
for d in dists:
    f_g = front.groupby('DISTANCE').get_group(d)
    t_g = tail.groupby('DISTANCE').get_group(d)


    plt.plot(f_g['CHANNEL'], f_g['RSSI'], c='r')
    plt.plot(t_g['CHANNEL'], t_g['RSSI'], c='g')
    
    plt.title(f)
    plt.show()
# for f in channels:
#     f_g = front.groupby('CHANNEL').get_group(f)
#     t_g = tail.groupby('CHANNEL').get_group(f)


#     plt.plot(f_g['DISTANCE'], f_g['RSSI'], c='r')
#     plt.plot(t_g['DISTANCE'], t_g['RSSI'], c='g')
    
#     plt.title(f)
#     plt.show()
