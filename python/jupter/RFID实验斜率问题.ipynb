# %%
from math import *

# %% [markdown]
# 实验数据的拟合
# ![image.png](attachment:0645d4f5-50ca-4439-921a-8a2e5406596b.png)

# %%
a = 0.367

# %% [markdown]
# 对应波长(cm)：

# %%
λ = 4*pi/a
λ
# Out:
# 34.24079186473889

# %% [markdown]
# 对应频率为

# %%
300/λ
# Out:
# 8.761479617208838

# %% [markdown]
# 而902.75到927.25对应的波长为

# %%
λ1 = 300/902.75
λ1
# Out:
# 0.33231791747438383

# %%
λ2 = 300/927.25
λ2
# Out:
# 0.3235373416015098

# %% [markdown]
# 按33cm算，应当是

# %%
4*pi / 33
# Out:
# 0.3807991095260355

# %% [markdown]
# 杨松臻说应该是实验的误差，比如我们测量的是tag距离天线的水平距离，如果天线的中心和tag没有对准的话，真实的距离就比测量值更大

# %% [markdown]
# 但是，斜率=$\delta \phi/\delta d$，若$\delta d$偏小，斜率应该偏大才对，但是实验是测量值偏小
